# %% [markdown]
# Progetto di Streaming Data Management and Time Series Analysis
#
# Riva Leonardo, 830647

# %%
# !pip install statsmodels -U

# %% [markdown]
# # Librerie

# %%
# generale
import pandas as pd
import numpy as np
import statsmodels
import holidays
import warnings
warnings.filterwarnings("ignore")

# statistica
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.structural import UnobservedComponents
from scipy.stats import linregress

# machine learning
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, ReLU, CuDNNGRU, CuDNNLSTM
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.callbacks import LambdaCallback, ModelCheckpoint
from keras import backend as K
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.model_selection import train_test_split

# grafici
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = (23,6)
import seaborn as sns
sns.set_style('darkgrid', {"axes.facecolor": "0.94"})
sns.set_color_codes(palette='pastel')

# drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# path = '/content/drive/MyDrive/'
path = '/content/drive/MyDrive/Università/5/Streaming data mng & time series analysis/Progetto/'

# %% [markdown]
# # Import file

# %%
df = pd.read_csv(path+'Project_data_2021_2022 (TRAINSET).csv')

# %%
df['Hour'] = df['Hour'].astype(str).apply(lambda x: x.zfill(2))
df['datetime'] = df['Date'] + ' ' + df['Hour']
df.drop(columns=['Date', 'Hour'], inplace=True)

# %%
df.columns = [x.lower() for x in df.columns]
df['datetime'] = pd.to_datetime(df.datetime, format='%Y-%m-%d %H')
df = df.set_index('datetime')
df.index = pd.DatetimeIndex(df.index.values, freq='h')

# %% [markdown]
# # Funzioni

# %%
def boxplot_distribution(df, x, y):
  ax = df.boxplot(by=x, column=y)
  plt.title('')
  plt.suptitle('')
  ax.set_title('');
  ax.set_xlabel(' ');
  ax.set_ylabel(' ');
  ax = plt.show()

# %%
def plot_acf_pacf(y, lags):
  fig, ax = plt.subplots(1, 2, figsize=(20,6))
  plot_acf(y, lags=lags, ax=ax[0], alpha=.05, zero=False, auto_ylims=True)
  plot_pacf(y, lags=lags, ax=ax[1], alpha=.05, zero=False, auto_ylims=True)
  plt.show()

# %%
def get_exog_sinusoids(n, period, df_train, df_test):
  omega = 2 * np.pi / period

  sinusoids = pd.DataFrame()

  for i in range(1, n+1):
    sinusoids['sin' + str(i)] = [np.sin(omega * i * x) for x in np.arange(len(df_train)+len(df_test))] 
    sinusoids['cos' + str(i)] = [np.cos(omega * i * x) for x in np.arange(len(df_train)+len(df_test))] 

  sinusoids.index = np.concatenate([df_train.index, df_test.index], axis=None)
  sinusoids.index = pd.DatetimeIndex(sinusoids.index.values, freq='h')

  sinusoids_train = sinusoids.iloc[:len(df_train)]
  sinusoids_test = sinusoids.iloc[len(df_train):]

  return sinusoids_train, sinusoids_test
  return sinusoids.index

# %%
def get_exog_dummies(df_train, df_test):
  hol = pd.DataFrame(data=['epifania', 'pasqua04', 'pasquetta04', 'festa_liberazione', 'festa_repubblica', 'antivigilia_natale', 'vigilia_natale', 'natale', 'pasqua05, pasquetta05'], 
                   index=['2004-01-05', '2004-04-11', '2004-04-12', '2004-04-25', '2004-06-01', '2004-12-23', '2004-12-24', '2004-12-25', '2005-03-27', '2005-03-28'])
  hol.index = pd.to_datetime(hol.index)
  hol_train = hol['2004-03-01':'2005-01-31']
  hol_test = hol['2005-02-01':'2005-02-28']

  tmp = pd.concat((df_train, hol_train), axis=1)
  exog_train = pd.get_dummies(tmp)
  del exog_train['co']

  tmp = pd.concat((df_val, hol_test), axis=1)
  exog_test = pd.get_dummies(tmp)
  del exog_test['co']
  for c in list(exog_train.columns):
    exog_test[c] = [0] * len(exog_test)

  return exog_train.copy(), exog_test.copy()

# %%
def predict(mod, start, end, exog_var=None, _log=True):
  if exog_var is None:
    pred = mod.get_prediction(start=start, end=end).predicted_mean
  else:
    pred = mod.get_prediction(start=start, end=end, exog=exog_var).predicted_mean

  if _log:
    pred = np.exp(pred)

  return pred

# %%
def knn_forecasting(series, h, p, k, operation='mean'):
  t = len(series)
  query = np.array(series[(t-p):t])
  idx_start = [-1] * k
  count = 0
  used_idxs = []

  while count < k:
    min_dist = np.inf

    for i in range(1, t-p-h): # il -h toglie la possibilità di usare i valori correnti per la previsione
      subseq = np.array(series[i:(i+p)])
      dist = np.linalg.norm(subseq - query) # distanza euclidea

      if dist < min_dist and i not in used_idxs:
        min_dist = dist
        idx_start[count] = i

    # è stata trovata una sottosequenza e non va più considerata
    used_idxs += list(range(idx_start[count], idx_start[count]+p))

    count += 1

  futuri = [series[(i+1):(i+h+1)] for i in idx_start]
  if operation == 'mean':
    futuro = np.mean(futuri, axis=0)
  elif operation == 'median':
    futuro = np.median(futuri, axis=0)
  else:
    print('ERROR!')
    return None

  return futuro.flatten()

# %%
def plot_prediction(groundtruth, prediction):
  plt.plot(groundtruth, label='True')
  plt.plot(prediction, label='Predicted')
  plt.legend(loc="upper right")
  plt.show()

# %%
def create_rrn_data(data, window, output=1):
  x = []
  y = []
  for i in range(len(data) - window - output):
    ts0 = data[i:(i+window)]
    ts1 = data[(i+window):(i+window+output)]
    x.append(ts0)
    y.append(ts1)
  return np.array(x), np.array(y)

# %%
def rnn_predict(model, h, current_batch, output=1):
  scaled_predictions = []
  for i in range(int(h/output)):
    pred = model.predict(current_batch)
    scaled_predictions += list(pred[0])
    current_batch = np.append(current_batch[:,output:,:], [np.array(pred[0]).reshape(-1,1)], axis=1) # aggiorna il batch con la nuova previsione, togliendo valore più vecchio
  return scaler.inverse_transform(np.array([scaled_predictions])).flatten()

# %% [markdown]
# # Esplorazione

# %%
df.head()
# Out:
#                          co
# 2004-03-10 18:00:00  1360.0
# 2004-03-10 19:00:00  1292.0
# 2004-03-10 20:00:00  1402.0
# 2004-03-10 21:00:00  1376.0
# 2004-03-10 22:00:00  1272.0

# %%
plt.plot(df['co'])

# %% [markdown]
# ### Distribuzione

# %%
boxplot_distribution(df, df.index.hour, 'co')
boxplot_distribution(df, df.index.dayofweek, 'co')

# %% [markdown]
# ### Stazionarietà in varianza

# %%
d1 = df.resample('m').mean()
x = list(d1['co'])
d2 = df.resample('m').std()
y = list(d2['co'])

# %%
plt.rcParams["figure.figsize"] = (10,10)

res = linregress(x,y)

mn = np.min(x)
mx = np.max(x)
x1 = np.linspace(mn,mx,500)
y1 = res.slope * x1 + res.intercept
plt.plot(x, y, 'ob')
plt.plot(x1, y1, '-r')
plt.show()

plt.rcParams["figure.figsize"] = (23,6)

# %%
print(res.rvalue)
print(res.pvalue)
# Out:
# 0.8624489813212881
# 0.00030642005398772137

# %% [markdown]
# ### Stazionarietà in media

# %%
def ad_test(ts):
  dftest = adfuller(ts.copy().dropna(), autolag='AIC', regression='n')
  print('ADF:', dftest[0])
  print('P-value:', dftest[1])
  print('Num of lags:', dftest[2])
  print('Num of observations used for ADF regression and critical values calculation:', dftest[3])
  print('Critical values:')
  for k,v in dftest[4].items():
    print('\t', k, ': ', v)

ad_test(df['co'])
# Out:
# ADF: -1.2383206644173417
# P-value: 0.1980623306620663
# Num of lags: 37
# Num of observations used for ADF regression and critical values calculation: 8123
# Critical values:
# 	 1% :  -2.5660152981053685
# 	 5% :  -1.9410331175406401
# 	 10% :  -1.6167873438050733

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Missing values

# %%
for i in range(len(df)):
  row = df.iloc[i]
  if np.isnan(row['co']):
    tmp = df.iloc[:(i-1)].copy().dropna() # prendo i precedenti non nulli
    tmp = tmp[(tmp.index.weekday==row.name.dayofweek) & (tmp.index.hour==row.name.hour)] # prendo quelli con stesso giorno e stessa ora
    df.iloc[i]['co'] = np.mean(tmp.iloc[-3:]['co']) # faccio la media degli ultimi 3 dati

# %%
plt.plot(df['co'])

# %% [markdown]
# ### Separazione in train e validation

# %%
df_train = df[df.index < '2005-02-01'].copy()
df_val = df[df.index >= '2005-02-01'].copy()

# %%
plt.plot(df_train)
plt.plot(df_val)
plt.show()

# %% [markdown]
# ### Log

# %%
df_train = np.log(df_train)

# %% [markdown]
# ### Save

# %%
df_train.to_csv(path+'df_train.csv', index=False)
df_val.to_csv(path+'df_val.csv', index=False)

# %% [markdown]
# # Read csv, per evitare ogni volta import e preprocessing

# %%
df_train = pd.read_csv(path+'df_train.csv')
df_val = pd.read_csv(path+'df_val.csv')

# %% [markdown]
# # ARIMA

# %% [markdown]
# ### Test iniziale
# - una differenza, per far fronte alla non stazionarietà in media
# - una differenza stagionale, per far fronte alla stagionalità giornaliera

# %%
plot_acf_pacf(df_train, 75)

# %%
mod1 = ARIMA(df_train, order=(0, 1, 0), seasonal_order=(0, 1, 0, 24)).fit()

# %%
plot_acf_pacf(mod1.resid, 75)

# %%
prediction1 = predict(mod1, df_val.index[0], df_val.index[-1])

aic1 = mod1.aic
mape1 = mape(df_val, prediction1)

print('AIC: ', int(aic1))
print('MAPE:', round(mape1, 4))
# Out:
# AIC:  -15516
# MAPE: 9.0658

# %%
del mod1

# %% [markdown]
# ### Modello 1
# - Aggiunta di un SMA(1), poiché acf va a 0 dopo 1 lag con stagionalità 24 osservazioni (un giorno)

# %%
mod1 = ARIMA(df_train, order=(0, 1, 0), seasonal_order=(0, 1, 1, 24)).fit()

# %%
plot_acf_pacf(mod1.resid, 75)

# %%
prediction1 = predict(mod1, df_val.index[0], df_val.index[-1])

aic1 = mod1.aic
mape1 = mape(df_val, prediction1)

print('AIC: ', int(aic1))
print('MAPE:', round(mape1, 4))
# Out:
# AIC:  -19660
# MAPE: 0.1187

# %%
plot_prediction(df_val, prediction1)

# %%
del mod1

# %% [markdown]
# ### Modello 2
# - Capire quali p e q usare: p=2 e q=2

# %%
# for i in [0,1,2,3]:
#   for j in [0,1,2,3]:
#     mod = ARIMA(df_train, order=(i, 1, j), seasonal_order=(0, 1, 1, 24)).fit()
#     prediction = predict(mod, df_val.index[0], df_val.index[-1])
#     print([i, j, mod.aic, mape(df_val, prediction)])
#     del mod

### RESULTS:
# [0, 0, -19661, 0.119]
# [0, 1, -19664, 0.118]
# [0, 2, -19834, 0.135]
# [0, 3, -19946, 0.178]
# [1, 0, -19662, 0.118]
# [1, 1, -20089, 0.124]
# [1, 2, -20214, 0.117]
# [1, 3, -20212, 0.118]
# [2, 0, -19798, 0.126]
# [2, 1, -20210, 0.120]
# [2, 2, -20213, 0.115]
# [2, 3, -20211, 0.118]
# [3, 0, -19844, 0.139]
# [3, 1, -20211, 0.117]
# [3, 2, -20209, 0.116]
# [3, 3, -20210, 0.116]

# %%
mod2 = ARIMA(df_train, order=(2, 1, 2), seasonal_order=(0, 1, 1, 24)).fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
plot_acf_pacf(mod2.resid, 600)

# %%
prediction2 = predict(mod2, df_val.index[0], df_val.index[-1])

aic2 = mod2.aic
mape2 = mape(df_val, prediction2)

print('AIC: ', int(aic2))
print('MAPE:', round(mape2, 4))
# Out:
# AIC:  -20212
# MAPE: 0.1152

# %%
del mod2

# %% [markdown]
# ### Modello 3
# - Aggiunta di regressori esterni sinusoidali, per modellare la stagionalità settimanale

# %%
# # grid search per capire quante sinusoidi usare
# for i in range(1,7):
#   sinusoids_train, sinusoids_val = get_exog_sinusoids(i, 24*7, df_train, df_val)
#   mod = ARIMA(df_train, order=(2, 1, 2), seasonal_order=(0, 1, 1, 24), exog=sinusoids_train).fit()
#   prediction = predict(mod, df_val.index[0], df_val.index[-1], exog_var=sinusoids_val)
#   a = mod.aic
#   m = mape(df_val, prediction)
#   print([i, round(a, 1), round(m, 3)])
#   del mod


### RESULT
# [1, -20240.7, 0.115]
# [2, -20220.6, 0.16]
# [3, -20249.6, 0.109]
# [4, -20201.2, 0.152]
# [5, -20306.5, 0.126]
# [6, -20374.5, 0.14]

# %%
best_n_sinusoids = 3
sinusoids_train, sinusoids_val = get_exog_sinusoids(best_n_sinusoids, 24*7, df_train, df_val)
sinusoids_val.head()
# Out:
#                          sin1          cos1  ...      sin3          cos3
# 2005-02-01 00:00:00 -1.000000  1.519491e-14  ...  1.000000  1.125870e-14
# 2005-02-01 01:00:00 -0.999301  3.739119e-02  ...  0.993712 -1.119645e-01
# 2005-02-01 02:00:00 -0.997204  7.473009e-02  ...  0.974928 -2.225209e-01
# 2005-02-01 03:00:00 -0.993712  1.119645e-01  ...  0.943883 -3.302791e-01
# 2005-02-01 04:00:00 -0.988831  1.490423e-01  ...  0.900969 -4.338837e-01
#
# [5 rows x 6 columns]

# %%
mod3 = ARIMA(df_train, order=(2, 1, 2), seasonal_order=(0, 1, 1, 24), exog=sinusoids_train).fit()

# %%
mod3.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
plot_acf_pacf(mod3.resid, 400)

# %%
prediction3 = predict(mod3, df_val.index[0], df_val.index[-1], exog_var=sinusoids_val)

aic3 = mod3.aic
mape3 = mape(df_val, prediction3)

print('AIC: ', int(aic3))
print('MAPE:', round(mape3, 4))
# Out:
# AIC:  -20249
# MAPE: 0.1094

# %%
plot_prediction(df_val, prediction3)

# %% [markdown]
# ### Modello 4
# - Aggiunta di regressori dummy per modellare le festività

# %%
def get_exog_dummies(df_train, df_test):
  hol = pd.DataFrame(data=['pasqua04', 'pasquetta04', 'festa_liberazione', 'festa_repubblica', 'antivigilia_natale',
                           'vigilia_natale', 'natale', 'epifania', 'pasqua05', 'pasquetta05'], 
                   index=['2004-04-11', '2004-04-12', '2004-04-25', '2004-06-01', '2004-12-23', 
                          '2004-12-24', '2004-12-25', '2005-01-05', '2005-03-27', '2005-03-28'])
  hol.index = pd.to_datetime(hol.index)
  hol_train = hol['2004-03-01':'2005-01-31']
  hol_test = hol['2005-02-01':'2005-02-28']

  tmp = pd.concat((df_train, hol_train), axis=1)
  exog_train = pd.get_dummies(tmp)
  del exog_train['co']

  tmp = pd.concat((df_val, hol_test), axis=1)
  exog_test = pd.get_dummies(tmp)
  del exog_test['co']
  for c in list(exog_train.columns):
    exog_test[c] = [0] * len(exog_test)

  return exog_train.copy(), exog_test.copy()


dummies_train, dummies_val = get_exog_dummies(df_train, df_val)
sinusoids_train, sinusoids_val = get_exog_sinusoids(best_n_sinusoids, 168, df_train, df_val)

exog_train = pd.concat([sinusoids_train, dummies_train], axis=1)
exog_val = pd.concat([sinusoids_val, dummies_val], axis=1)

# %%
mod4 = ARIMA(df_train, order=(2, 1, 2), seasonal_order=(0, 1, 1, 24), exog=exog_train).fit()

# %%
prediction4 = predict(mod4, df_val.index[0], df_val.index[-1], exog_var=exog_val)

aic4 = mod4.aic
mape4 = mape(df_val, prediction4)

print('AIC: ', int(aic4))
print('MAPE:', round(mape4, 4)*100)
# Out:
# AIC:  -20262
# MAPE: 11.14

# %% [markdown]
# ### Analisi finale dei residui

# %%
from scipy import stats

x = mod3.resid

k2, p = stats.normaltest(x)
alpha = 0.05
print("p = {:g}".format(p))

if p < alpha:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis can be rejected")
else:
    print("The null hypothesis cannot be rejected")

# %%
sns.displot(mod4.resid, height=8, aspect=16/8)

# %% [markdown]
# ### Confronto

# %%
tmp = pd.DataFrame([[mape1, mape2, mape3, mape4]], columns=['mod1', 'mod2', 'mod3', 'mod4'], index = ['mape'])
tmp = np.round(tmp*100, 2)
tmp
# Out:
#        mod1   mod2   mod3   mod4
# mape  11.87  11.52  10.94  10.87

# %%
plot_prediction(df_val, prediction1)
plot_prediction(df_val, prediction2)
plot_prediction(df_val, prediction3)
plot_prediction(df_val, prediction4)

# %% [markdown]
# # UCM

# %%
initial_variance = np.var(df_train)

# %% [markdown]
# ### grid search

# %%
levels = ['ntrend', 'dconstant', 'llevel', 'rwalk', 'lldtrend', 'rwdrift', 'lltrend', 'strend', 'rtrend']
result = []

for l in levels:
  mod1 = UnobservedComponents(df_train, 
                              level = l,
                              seasonal = 24)
  mod1.initial_variance = initial_variance
  mod1 = mod1.fit()

  prediction1 = predict(mod1, df_val.index[0], df_val.index[-1])
  result.append([l, int(mod1.aic), 100*round(mape(df_val, prediction1), 4)])
  del mod1

pd.DataFrame(result, columns=['level_type', 'AIC', 'MAPE']).sort_values(by='AIC')
# Out:
#   level_type    AIC    MAPE
# 3      rwalk -19406  0.1222
# 2     llevel -19404  0.1222
# 5    rwdrift -19400  0.1208
# 4   lldtrend -19398  0.1208
# 6    lltrend -19396  0.1208
# 7     strend -16584  0.9773
# 8     rtrend -14535  0.9697
# 1  dconstant  -6288  0.1194
# 0     ntrend  52827  0.9991

# %%
harmonics = [2,3,4,5,6,7,8,9,10]
result = []

for i in harmonics:
  mod1 = UnobservedComponents(df_train, 
                              level = 'rwdrift',
                              seasonal = 24,
                              freq_seasonal = [{'period': 168, 'harmonics': i}])
  mod1.initial_variance = initial_variance
  mod1 = mod1.fit()

  prediction1 = predict(mod1, df_val.index[0], df_val.index[-1])
  result.append([i, int(mod1.aic), 100*round(mape(df_val, prediction1), 4)])
  del mod1

pd.DataFrame(result, columns=['level_type', 'AIC', 'MAPE']).sort_values(by='AIC')
# Out:
#    level_type    AIC   MAPE
# 0           2 -19337  11.65
# 1           3 -19296  11.58
# 2           4 -19259  11.73
# 5           7 -19253  12.63
# 6           8 -19247  13.17
# 7           9 -19235  14.00
# 3           5 -19230  12.67
# 4           6 -19226  13.43
# 8          10 -19195  14.21

# %%
# test sulle sinusoidi
harmonics_daily = [2,3,4,5,6,7,8]
harmonics_weekly = [2,3,4,5,6]
result = []

for i in harmonics_daily:
  for j in harmonics_weekly:
    mod1 = UnobservedComponents(df_train, 
                                level = 'rwdrift',
                                freq_seasonal = [{'period': 24, 'harmonics': i}, {'period': 168, 'harmonics': j}])
    mod1.initial_variance = initial_variance
    mod1 = mod1.fit(method='newton')

    prediction1 = predict(mod1, df_val.index[0], df_val.index[-1])
    result.append([i, j, int(mod1.aic), 100*round(mape(df_val, prediction1), 4)])
    del mod1

pd.DataFrame(result, columns=['sinusoids_daily', 'sinusoids_weekly', 'AIC', 'MAPE']).sort_values(by='AIC')

# %%
# test sul cycle
for i in [True, False]:
  mod1 = UnobservedComponents(df_train, 
                              level = 'rwdrift',
                              cycle = i,
                              freq_seasonal = [{'period': 24, 'harmonics': 6}, {'period': 168, 'harmonics': 2}])
  mod1.initial_variance = initial_variance
  mod1 = mod1.fit()

  prediction1 = predict(mod1, df_val.index[0], df_val.index[-1])
  print([i, int(mod1.aic), 100*round(mape(df_val, prediction1), 4)])
  del mod1
# Out:
# [True, -19375, 11.469999999999999]
# [False, -19414, 11.51]

# %%
# test sui tipi di cycle
for i in [True, False]:
  for j in [True, False]:
    mod1 = UnobservedComponents(df_train, 
                                level = 'rwdrift',
                                cycle = True, 
                                stochastic_cycle = i,
                                damped_cycle = j, 
                                freq_seasonal = [{'period': 24, 'harmonics': 6}, {'period': 168, 'harmonics': 2}])
    mod1.initial_variance = initial_variance
    mod1 = mod1.fit()

    prediction1 = predict(mod1, df_val.index[0], df_val.index[-1])
    print([i, j, int(mod1.aic), 100*round(mape(df_val, prediction1), 4)])
    del mod1
# Out:
# [True, True, -19415, 11.58]
# [True, False, -19399, 11.52]
# [False, True, -19409, 11.59]
# [False, False, -19375, 11.469999999999999]

# %%
# test con parte autoregressiva
for i in [None,1,2,3,4,5]:
  mod1 = UnobservedComponents(df_train, 
                              level = 'rwdrift',
                              autoregressive = i,
                              freq_seasonal = [{'period': 24, 'harmonics': 6}, {'period': 168, 'harmonics': 2}])
  mod1.initial_variance = initial_variance
  mod1 = mod1.fit()

  prediction1 = predict(mod1, df_val.index[0], df_val.index[-1])
  print([i, int(mod1.aic), 100*round(mape(df_val, prediction1), 4)])
  del mod1
# Out:
# [None, -19414, 11.51]
# [1, -19912, 11.129999999999999]
# [2, -19548, 12.83]
# [3, -19908, 11.59]
# [4, -19928, 11.81]
# [5, -19845, 12.41]

# %%
# test con dummies
dummies_train, dummies_val = get_exog_dummies(df_train, df_val)
mod1 = UnobservedComponents(df_train, 
                            'rwdrift',
                            freq_seasonal = [{'period': 24, 'harmonics': 6}, {'period': 168, 'harmonics': 2}],
                            exog = dummies_train)
mod1.initial_variance = initial_variance
mod1 = mod1.fit()
prediction1 = predict(mod1, df_val.index[0], df_val.index[-1], exog_var=dummies_val)
print([int(mod1.aic), 100*round(mape(df_val, prediction1), 4)])
# Out:
# [-19413, 11.5]

# %% [markdown]
# ### migliore

# %%
mod1 = UnobservedComponents(df_train, 
                            'rwdrift',
                            autoregressive = 1,
                            freq_seasonal = [{'period': 24, 'harmonics': 6}, {'period': 168, 'harmonics': 2}])
mod1.initial_variance = initial_variance
mod1 = mod1.fit()

# %%
mod1.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
prediction1 = predict(mod1, start=df_val.index[0], end=df_val.index[-1])

aic1 = mod1.aic
mape1 = mape(df_val, prediction1)

print('AIC: ', int(aic1))
print('MAPE:', round(mape1, 4))
# Out:
# AIC:  -19912
# MAPE: 0.1113

# %%
plot_prediction(df_val['co'], prediction1)

# %% [markdown]
# # ML

# %%
df_train = np.exp(df_train)

# %%
look_back = 24*7*3
batch_size = 128
epochs = 100
patience = 3
output = 168

# %%
# prepare data
scaler = MinMaxScaler(feature_range = (0, 1))
scaled_train = scaler.fit_transform(df_train)

X_train, y_train = create_rrn_data(scaled_train, look_back, output)
print(X_train.shape, y_train.shape)
# Out:
# (7182, 504, 1) (7182, 168, 1)

# %% [markdown]
# ### KNN
# predice h valori (orizzonte), sulla base di k valori passati, mediando i futuri delle p sottosequenze più simili

# %%
result = []

for p in [12, 24, 24*2, 24*4, 24*7, 24*14, 24*21, 24*28]:
  print(p)
  for k in [4,8,16,32,64]: #range(4, 21, 2):
    prediction = knn_forecasting(df_train, len(df_val), p, k, 'median')
    result.append([k, p, mape(df_val, prediction)*100])

df_result = pd.DataFrame(result, columns=['k', 'p', 'mape']).sort_values(by='mape')
best = df_result.iloc[0]

df_result
# Out:
# 12
# 24
# 48
# 96
# 168
# 336
# 504
# 672
#      k    p       mape
# 31   8  504  10.130239
# 32  16  504  10.379490
# 33  32  504  10.493065
# 24  64  168  10.980073
# 30   4  504  11.048968
# 23  32  168  11.390631
# 13  32   48  11.452806
# 25   4  336  11.473536
# 14  64   48  11.503649
# 38  32  672  11.532620
# 26   8  336  11.586771
# 22  16  168  11.648474
# 27  16  336  11.685671
# 21   8  168  11.842477
# 28  32  336  11.858017
# 12  16   48  11.913698
# 29  64  336  12.344165
# 34  64  504  12.413716
# 37  16  672  12.447238
# 9   64   24  12.545882
# 36   8  672  12.847645
# 10   4   48  12.896068
# 11   8   48  13.082822
# 35   4  672  13.128354
# 19  64   96  13.291370
# 8   32   24  13.365670
# 18  32   96  13.615939
# 5    4   24  13.779330
# 39  64  672  13.924615
# 7   16   24  14.084646
# 16   8   96  14.421573
# 17  16   96  14.537472
# 20   4  168  14.604950
# 6    8   24  15.017438
# 15   4   96  16.092614
# 4   64   12  16.577990
# 3   32   12  16.854952
# 2   16   12  17.056221
# 1    8   12  17.545589
# 0    4   12  18.655632

# %%
prediction = knn_forecasting(df_train, len(df_val), int(best['p']), int(best['k']))
plot_prediction(list(df_val['co']), prediction)

# %% [markdown]
# ### LSTM

# %%
K.clear_session()
tf.random.set_seed(123)

# %%
model = Sequential()

model.add(CuDNNLSTM(units=512, return_sequences=True, input_shape=(look_back, 1)))

model.add(ReLU())

model.add(Dropout(.2))

model.add(CuDNNLSTM(units=256, return_sequences=False))

model.add(ReLU())

model.add(Dropout(.2))

model.add(Dense(output))


model.compile(optimizer=Adam(learning_rate=0.0005), loss='mae')

# %%
global mapes
mapes = []
current_batch = scaled_train[-look_back:].reshape((1, look_back, 1))

def testAfterEpochs(epoch, _):
  global best_mape
  predictions = rnn_predict(model, len(df_val), current_batch, output)
  mape_lstm = mape(df_val, predictions)
  print('val_mape:', round(mape_lstm, 4))
  mapes.append(mape_lstm)
  if mape_lstm <= np.min(mapes):
    model.save(path+'best_model.h5')

stop_callback = keras.callbacks.EarlyStopping(monitor='loss', patience=patience)
mape_callback = LambdaCallback(on_epoch_end = testAfterEpochs)

net_hist = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, callbacks=[mape_callback, stop_callback], verbose=2)
# Out:
# Epoch 1/100
# val_mape: 0.128
# 57/57 - 45s - loss: 0.1669 - 45s/epoch - 793ms/step
# Epoch 2/100
# val_mape: 0.1288
# 57/57 - 36s - loss: 0.1274 - 36s/epoch - 637ms/step
# Epoch 3/100
# val_mape: 0.128
# 57/57 - 36s - loss: 0.1237 - 36s/epoch - 636ms/step
# Epoch 4/100
# val_mape: 0.1223
# 57/57 - 37s - loss: 0.1170 - 37s/epoch - 645ms/step
# Epoch 5/100
# val_mape: 0.1219
# 57/57 - 37s - loss: 0.1098 - 37s/epoch - 648ms/step
# Epoch 6/100
# val_mape: 0.1859
# 57/57 - 36s - loss: 0.1055 - 36s/epoch - 638ms/step
# Epoch 7/100
# val_mape: 0.1305
# 57/57 - 36s - loss: 0.1068 - 36s/epoch - 638ms/step
# Epoch 8/100
# val_mape: 0.1635
# 57/57 - 36s - loss: 0.1024 - 36s/epoch - 639ms/step
# Epoch 9/100
# val_mape: 0.1306
# 57/57 - 36s - loss: 0.1009 - 36s/epoch - 639ms/step
# Epoch 10/100
# val_mape: 0.1399
# 57/57 - 36s - loss: 0.0993 - 36s/epoch - 638ms/step
# Epoch 11/100
# val_mape: 0.1575
# 57/57 - 36s - loss: 0.0985 - 36s/epoch - 639ms/step
# Epoch 12/100
# val_mape: 0.1439
# 57/57 - 36s - loss: 0.0981 - 36s/epoch - 638ms/step
# Epoch 13/100
# val_mape: 0.1345
# 57/57 - 36s - loss: 0.0968 - 36s/epoch - 639ms/step
# Epoch 14/100
# val_mape: 0.1451
# 57/57 - 36s - loss: 0.0963 - 36s/epoch - 639ms/step
# Epoch 15/100
# val_mape: 0.1138
# 57/57 - 37s - loss: 0.0962 - 37s/epoch - 647ms/step
# Epoch 16/100
# val_mape: 0.1193
# 57/57 - 36s - loss: 0.0952 - 36s/epoch - 638ms/step
# Epoch 17/100
# val_mape: 0.1594
# 57/57 - 36s - loss: 0.0946 - 36s/epoch - 639ms/step
# Epoch 18/100
# val_mape: 0.1189
# 57/57 - 36s - loss: 0.0944 - 36s/epoch - 639ms/step
# Epoch 19/100
# val_mape: 0.1208
# 57/57 - 36s - loss: 0.0937 - 36s/epoch - 638ms/step
# Epoch 20/100
# val_mape: 0.1362
# 57/57 - 36s - loss: 0.0930 - 36s/epoch - 638ms/step
# Epoch 21/100
# val_mape: 0.1328
# 57/57 - 36s - loss: 0.0929 - 36s/epoch - 639ms/step
# Epoch 22/100
# val_mape: 0.1188
# 57/57 - 36s - loss: 0.0918 - 36s/epoch - 638ms/step
# Epoch 23/100
# val_mape: 0.1352
# 57/57 - 36s - loss: 0.0911 - 36s/epoch - 638ms/step
# Epoch 24/100
# val_mape: 0.1204
# 57/57 - 36s - loss: 0.0901 - 36s/epoch - 638ms/step
# Epoch 25/100
# val_mape: 0.1306
# 57/57 - 36s - loss: 0.0876 - 36s/epoch - 639ms/step
# Epoch 26/100
# val_mape: 0.1108
# 57/57 - 37s - loss: 0.0881 - 37s/epoch - 647ms/step
# Epoch 27/100
# val_mape: 0.1703
# 57/57 - 36s - loss: 0.0885 - 36s/epoch - 637ms/step
# Epoch 28/100
# val_mape: 0.1065
# 57/57 - 37s - loss: 0.0893 - 37s/epoch - 647ms/step

# %%
plt.rcParams["figure.figsize"] = (12,8)
plt.plot(net_hist.history['loss'], label='train')
plt.plot(mapes, label='validation')
plt.legend(loc='upper right')
plt.show()
plt.rcParams["figure.figsize"] = (23,6)

# %%
model = keras.models.load_model(path+'best_model.h5')

# %%
current_batch = scaled_train[-look_back:].reshape((1, look_back, 1)) # ultimi N valori del train
predictions = rnn_predict(model, len(df_val), current_batch, output)

# %%
mape_lstm = mape(df_val, predictions)*100
print(round(mape_lstm, 2))
plot_prediction(list(df_val['co']), predictions)
# Out:
# 10.65

# %% [markdown]
# ### GRU

# %%
K.clear_session()
tf.random.set_seed(123)

# %%
model = Sequential()

model.add(CuDNNGRU(units=512, return_sequences=True, input_shape=(look_back, 1)))

model.add(ReLU())

model.add(Dropout(.2))

model.add(CuDNNGRU(units=256, return_sequences=False))

model.add(ReLU())

model.add(Dropout(.2))

model.add(Dense(output))


model.compile(optimizer=Adam(learning_rate=0.0005), loss='mae')

# %%
global mapes
mapes = []
current_batch = scaled_train[-look_back:].reshape((1, look_back, 1))

def testAfterEpochs(epoch, _):
  global best_mape
  predictions = rnn_predict(model, len(df_val), current_batch, output)
  mape_gru = mape(df_val, predictions)
  print('val_mape:', round(mape_gru, 4))
  mapes.append(mape_gru)
  if mape_gru <= np.min(mapes):
    model.save(path+'best_model.h5')

stop_callback = keras.callbacks.EarlyStopping(monitor='loss', patience=patience)
mape_callback = LambdaCallback(on_epoch_end = testAfterEpochs)

net_hist = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, callbacks=[mape_callback, stop_callback], verbose=2)
# Out:
# Epoch 1/100
# val_mape: 0.1272
# 57/57 - 33s - loss: 0.1729 - 33s/epoch - 587ms/step
# Epoch 2/100
# val_mape: 0.1276
# 57/57 - 30s - loss: 0.1267 - 30s/epoch - 523ms/step
# Epoch 3/100
# val_mape: 0.126
# 57/57 - 30s - loss: 0.1235 - 30s/epoch - 533ms/step
# Epoch 4/100
# val_mape: 0.1247
# 57/57 - 30s - loss: 0.1201 - 30s/epoch - 535ms/step
# Epoch 5/100
# val_mape: 0.1241
# 57/57 - 31s - loss: 0.1140 - 31s/epoch - 542ms/step
# Epoch 6/100
# val_mape: 0.183
# 57/57 - 30s - loss: 0.1096 - 30s/epoch - 533ms/step
# Epoch 7/100
# val_mape: 0.1223
# 57/57 - 31s - loss: 0.1052 - 31s/epoch - 543ms/step
# Epoch 8/100
# val_mape: 0.1543
# 57/57 - 31s - loss: 0.1048 - 31s/epoch - 536ms/step
# Epoch 9/100
# val_mape: 0.1533
# 57/57 - 31s - loss: 0.1022 - 31s/epoch - 536ms/step
# Epoch 10/100
# val_mape: 0.1501
# 57/57 - 31s - loss: 0.1008 - 31s/epoch - 535ms/step
# Epoch 11/100
# val_mape: 0.1491
# 57/57 - 31s - loss: 0.1006 - 31s/epoch - 536ms/step
# Epoch 12/100
# val_mape: 0.1249
# 57/57 - 31s - loss: 0.0998 - 31s/epoch - 537ms/step
# Epoch 13/100
# val_mape: 0.1232
# 57/57 - 31s - loss: 0.0989 - 31s/epoch - 537ms/step
# Epoch 14/100
# val_mape: 0.1286
# 57/57 - 31s - loss: 0.0988 - 31s/epoch - 537ms/step
# Epoch 15/100
# val_mape: 0.1184
# 57/57 - 31s - loss: 0.0980 - 31s/epoch - 545ms/step
# Epoch 16/100
# val_mape: 0.118
# 57/57 - 31s - loss: 0.0975 - 31s/epoch - 546ms/step
# Epoch 17/100
# val_mape: 0.1396
# 57/57 - 31s - loss: 0.0979 - 31s/epoch - 539ms/step
# Epoch 18/100
# val_mape: 0.1336
# 57/57 - 31s - loss: 0.0966 - 31s/epoch - 538ms/step
# Epoch 19/100
# val_mape: 0.1258
# 57/57 - 31s - loss: 0.0961 - 31s/epoch - 539ms/step
# Epoch 20/100
# val_mape: 0.1339
# 57/57 - 31s - loss: 0.0960 - 31s/epoch - 538ms/step
# Epoch 21/100
# val_mape: 0.1227
# 57/57 - 31s - loss: 0.0951 - 31s/epoch - 537ms/step
# Epoch 22/100
# val_mape: 0.1387
# 57/57 - 31s - loss: 0.0943 - 31s/epoch - 536ms/step
# Epoch 23/100
# val_mape: 0.1272
# 57/57 - 30s - loss: 0.0934 - 30s/epoch - 535ms/step
# Epoch 24/100
# val_mape: 0.1385
# 57/57 - 31s - loss: 0.0930 - 31s/epoch - 537ms/step
# Epoch 25/100
# val_mape: 0.1557
# 57/57 - 31s - loss: 0.0926 - 31s/epoch - 537ms/step
# Epoch 26/100
# val_mape: 0.1186
# 57/57 - 31s - loss: 0.0911 - 31s/epoch - 539ms/step
# Epoch 27/100
# val_mape: 0.1335
# 57/57 - 31s - loss: 0.0912 - 31s/epoch - 538ms/step
# Epoch 28/100
# val_mape: 0.1232
# 57/57 - 31s - loss: 0.0895 - 31s/epoch - 539ms/step
# Epoch 29/100
# val_mape: 0.1284
# 57/57 - 31s - loss: 0.0881 - 31s/epoch - 540ms/step
# Epoch 30/100
# val_mape: 0.1116
# 57/57 - 31s - loss: 0.0870 - 31s/epoch - 545ms/step
# Epoch 31/100
# val_mape: 0.1274
# 57/57 - 31s - loss: 0.0861 - 31s/epoch - 536ms/step
# Epoch 32/100
# val_mape: 0.1214
# 57/57 - 31s - loss: 0.0836 - 31s/epoch - 536ms/step
# Epoch 33/100
# val_mape: 0.1254
# 57/57 - 31s - loss: 0.0837 - 31s/epoch - 538ms/step
# Epoch 34/100
# val_mape: 0.1344
# 57/57 - 31s - loss: 0.0811 - 31s/epoch - 536ms/step
# Epoch 35/100
# val_mape: 0.1337
# 57/57 - 31s - loss: 0.0800 - 31s/epoch - 536ms/step
# Epoch 36/100
# val_mape: 0.1288
# 57/57 - 31s - loss: 0.0793 - 31s/epoch - 538ms/step
# Epoch 37/100
# val_mape: 0.1389
# 57/57 - 31s - loss: 0.0786 - 31s/epoch - 537ms/step
# Epoch 38/100
# val_mape: 0.1344
# 57/57 - 31s - loss: 0.0757 - 31s/epoch - 536ms/step
# Epoch 39/100
# val_mape: 0.1358
# 57/57 - 31s - loss: 0.0761 - 31s/epoch - 536ms/step
# Epoch 40/100
# val_mape: 0.1353
# 57/57 - 31s - loss: 0.0751 - 31s/epoch - 538ms/step
# Epoch 41/100
# val_mape: 0.1464
# 57/57 - 31s - loss: 0.0738 - 31s/epoch - 538ms/step
# Epoch 42/100
# val_mape: 0.1425
# 57/57 - 31s - loss: 0.0733 - 31s/epoch - 537ms/step
# Epoch 43/100
# val_mape: 0.1386
# 57/57 - 31s - loss: 0.0717 - 31s/epoch - 538ms/step
# Epoch 44/100
# val_mape: 0.1425
# 57/57 - 31s - loss: 0.0719 - 31s/epoch - 538ms/step
# Epoch 45/100
# val_mape: 0.1561
# 57/57 - 31s - loss: 0.0703 - 31s/epoch - 538ms/step
# Epoch 46/100
# val_mape: 0.1421
# 57/57 - 31s - loss: 0.0699 - 31s/epoch - 537ms/step
# Epoch 47/100
# val_mape: 0.1401
# 57/57 - 31s - loss: 0.0689 - 31s/epoch - 538ms/step
# Epoch 48/100
# val_mape: 0.1264
# 57/57 - 31s - loss: 0.0680 - 31s/epoch - 537ms/step
# Epoch 49/100
# val_mape: 0.1467
# 57/57 - 31s - loss: 0.0676 - 31s/epoch - 536ms/step
# Epoch 50/100
# val_mape: 0.1408
# 57/57 - 31s - loss: 0.0668 - 31s/epoch - 536ms/step
# Epoch 51/100
# val_mape: 0.1419
# 57/57 - 31s - loss: 0.0674 - 31s/epoch - 537ms/step
# Epoch 52/100
# val_mape: 0.1451
# 57/57 - 31s - loss: 0.0659 - 31s/epoch - 539ms/step
# Epoch 53/100
# val_mape: 0.1651
# 57/57 - 31s - loss: 0.0652 - 31s/epoch - 538ms/step
# Epoch 54/100
# val_mape: 0.1274
# 57/57 - 31s - loss: 0.0654 - 31s/epoch - 536ms/step
# Epoch 55/100
# val_mape: 0.1693
# 57/57 - 31s - loss: 0.0645 - 31s/epoch - 535ms/step
# Epoch 56/100
# val_mape: 0.17
# 57/57 - 31s - loss: 0.0639 - 31s/epoch - 538ms/step
# Epoch 57/100
# val_mape: 0.1503
# 57/57 - 31s - loss: 0.0634 - 31s/epoch - 540ms/step
# Epoch 58/100
# val_mape: 0.1455
# 57/57 - 31s - loss: 0.0629 - 31s/epoch - 537ms/step
# Epoch 59/100
# val_mape: 0.1561
# 57/57 - 31s - loss: 0.0624 - 31s/epoch - 536ms/step
# Epoch 60/100
# val_mape: 0.1457
# 57/57 - 31s - loss: 0.0625 - 31s/epoch - 537ms/step
# Epoch 61/100
# val_mape: 0.1452
# 57/57 - 31s - loss: 0.0618 - 31s/epoch - 537ms/step
# Epoch 62/100
# val_mape: 0.1722
# 57/57 - 31s - loss: 0.0615 - 31s/epoch - 537ms/step
# Epoch 63/100
# val_mape: 0.1629
# 57/57 - 31s - loss: 0.0607 - 31s/epoch - 537ms/step
# Epoch 64/100
# val_mape: 0.1513
# 57/57 - 31s - loss: 0.0606 - 31s/epoch - 538ms/step
# Epoch 65/100
# val_mape: 0.1783
# 57/57 - 31s - loss: 0.0601 - 31s/epoch - 538ms/step
# Epoch 66/100
# val_mape: 0.1435
# 57/57 - 31s - loss: 0.0598 - 31s/epoch - 537ms/step
# Epoch 67/100
# val_mape: 0.179
# 57/57 - 31s - loss: 0.0595 - 31s/epoch - 536ms/step
# Epoch 68/100
# val_mape: 0.1737
# 57/57 - 31s - loss: 0.0593 - 31s/epoch - 535ms/step
# Epoch 69/100
# val_mape: 0.1692
# 57/57 - 31s - loss: 0.0588 - 31s/epoch - 537ms/step
# Epoch 70/100
# val_mape: 0.1653
# 57/57 - 31s - loss: 0.0585 - 31s/epoch - 537ms/step
# Epoch 71/100
# val_mape: 0.1692
# 57/57 - 31s - loss: 0.0580 - 31s/epoch - 538ms/step
# Epoch 72/100
# val_mape: 0.1756
# 57/57 - 31s - loss: 0.0579 - 31s/epoch - 537ms/step
# Epoch 73/100
# val_mape: 0.1694
# 57/57 - 31s - loss: 0.0577 - 31s/epoch - 537ms/step
# Epoch 74/100
# val_mape: 0.1811
# 57/57 - 31s - loss: 0.0574 - 31s/epoch - 537ms/step
# Epoch 75/100
# val_mape: 0.171
# 57/57 - 31s - loss: 0.0571 - 31s/epoch - 536ms/step
# Epoch 76/100
# val_mape: 0.1685
# 57/57 - 31s - loss: 0.0566 - 31s/epoch - 538ms/step
# Epoch 77/100
# val_mape: 0.1745
# 57/57 - 31s - loss: 0.0564 - 31s/epoch - 538ms/step
# Epoch 78/100
# val_mape: 0.1403
# 57/57 - 31s - loss: 0.0563 - 31s/epoch - 536ms/step
# Epoch 79/100
# val_mape: 0.1439
# 57/57 - 31s - loss: 0.0566 - 31s/epoch - 540ms/step
# Epoch 80/100
# val_mape: 0.1486
# 57/57 - 31s - loss: 0.0554 - 31s/epoch - 538ms/step
# Epoch 81/100
# val_mape: 0.1415
# 57/57 - 31s - loss: 0.0555 - 31s/epoch - 538ms/step
# Epoch 82/100
# val_mape: 0.1346
# 57/57 - 31s - loss: 0.0550 - 31s/epoch - 536ms/step
# Epoch 83/100
# val_mape: 0.1291
# 57/57 - 31s - loss: 0.0549 - 31s/epoch - 536ms/step
# Epoch 84/100
# val_mape: 0.1366
# 57/57 - 31s - loss: 0.0548 - 31s/epoch - 538ms/step
# Epoch 85/100
# val_mape: 0.1445
# 57/57 - 31s - loss: 0.0544 - 31s/epoch - 538ms/step
# Epoch 86/100
# val_mape: 0.1328
# 57/57 - 31s - loss: 0.0541 - 31s/epoch - 536ms/step
# Epoch 87/100
# val_mape: 0.1676
# 57/57 - 31s - loss: 0.0539 - 31s/epoch - 536ms/step
# Epoch 88/100
# val_mape: 0.1427
# 57/57 - 31s - loss: 0.0540 - 31s/epoch - 537ms/step
# Epoch 89/100
# val_mape: 0.1318
# 57/57 - 31s - loss: 0.0535 - 31s/epoch - 537ms/step
# Epoch 90/100
# val_mape: 0.1546
# 57/57 - 31s - loss: 0.0534 - 31s/epoch - 537ms/step
# Epoch 91/100
# val_mape: 0.1298
# 57/57 - 31s - loss: 0.0532 - 31s/epoch - 536ms/step
# Epoch 92/100
# val_mape: 0.1401
# 57/57 - 31s - loss: 0.0530 - 31s/epoch - 537ms/step
# Epoch 93/100
# val_mape: 0.1461
# 57/57 - 31s - loss: 0.0528 - 31s/epoch - 537ms/step
# Epoch 94/100
# val_mape: 0.1544
# 57/57 - 31s - loss: 0.0526 - 31s/epoch - 537ms/step
# Epoch 95/100
# val_mape: 0.1368
# 57/57 - 31s - loss: 0.0523 - 31s/epoch - 539ms/step
# Epoch 96/100
# val_mape: 0.1251
# 57/57 - 31s - loss: 0.0521 - 31s/epoch - 540ms/step
# Epoch 97/100
# val_mape: 0.1419
# 57/57 - 31s - loss: 0.0522 - 31s/epoch - 538ms/step
# Epoch 98/100
# val_mape: 0.1461
# 57/57 - 31s - loss: 0.0519 - 31s/epoch - 536ms/step
# Epoch 99/100
# val_mape: 0.1397
# 57/57 - 31s - loss: 0.0516 - 31s/epoch - 537ms/step
# Epoch 100/100
# val_mape: 0.1362
# 57/57 - 31s - loss: 0.0513 - 31s/epoch - 536ms/step

# %%
# stop_callback = keras.callbacks.EarlyStopping(monitor='loss', patience=patience)
# net_hist = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=epochs, batch_size=batch_size, callbacks=[stop_callback])

# %%
plt.rcParams["figure.figsize"] = (12,8)
plt.plot(net_hist.history['loss'], label='train')
plt.plot(mapes, label='validation')
plt.legend(loc='upper right')
plt.show()
plt.rcParams["figure.figsize"] = (23,6)

# %%
model = keras.models.load_model(path+'best_model.h5')

# %%
current_batch = scaled_train[-look_back:].reshape((1, look_back, 1)) # ultimi N valori del train
predictions = rnn_predict(model, len(df_val), current_batch, output)

# %%
mape_gru = mape(df_val, predictions)*100
print(round(mape_gru, 2))
plot_prediction(list(df_val['co']), predictions)
# Out:
# 11.16

# %% [markdown]
# # Previsione su marzo 2005

# %%
df_log = pd.concat([df_train, np.log(df_val)])
df = np.exp(df_log)

# %% [markdown]
# ### ARIMA

# %%
idx = pd.date_range(start='2005-03-01 00:00:00', end='2005-03-31 23:00:00', freq='h')
df_test = pd.DataFrame([None]*len(idx), index=idx)
sinusoids_train, sinusoids_test = get_exog_sinusoids(3, 168, df, df_test)

# %%
mod = ARIMA(df_log, order=(2, 1, 2), seasonal_order=(0, 1, 1, 24), exog=sinusoids_train).fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:606: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
prediction_arima = predict(mod, df_test.index[0], df_test.index[-1], exog_var=sinusoids_test)

plt.plot(df)
plt.plot(prediction_arima)
plt.show()

plt.plot(df['2005-02-01':'2005-04-01'])
plt.plot(prediction_arima['2005-02-01':'2005-04-01'])
plt.show()

# %% [markdown]
# ### UCM

# %%
mod = UnobservedComponents(df_log, 
                           'rwdrift',
                           autoregressive = 1,
                           freq_seasonal = [{'period': 24, 'harmonics': 6}, {'period': 168, 'harmonics': 2}])
mod.initial_variance = np.var(df_log)
mod = mod.fit()

# %%
prediction_ucm = predict(mod, start=df_test.index[0], end=df_test.index[-1])

plt.plot(df)
plt.plot(prediction_ucm)
plt.show()

plt.plot(df['2005-02-01':'2005-04-01'])
plt.plot(prediction_ucm['2005-02-01':'2005-04-01'])
plt.show()

# %% [markdown]
# ### ML

# %%
p = 24*21
k = 8
prediction_ml = knn_forecasting(df, len(df_test), p, k)

plt.plot(list(df['co']))
plt.plot(range(len(df), len(df)+len(prediction_ml)), prediction_ml)
plt.show()

tmp = list(df['2005-02-01':'2005-04-01']['co'])
plt.plot(tmp)
plt.plot(range(len(tmp), len(tmp)+len(prediction_ml)), prediction_ml)
plt.show()

# %% [markdown]
# ### Salvataggio su file

# %%
dfp = pd.DataFrame(prediction_arima)
dfp.columns=['ARIMA']
dfp['Date'] = dfp.index.date
dfp['Hour'] = dfp.index.hour
dfp['UCM'] = list(prediction_ucm)
dfp['ML'] = list(prediction_ml)
dfp[['Date', 'Hour', 'ARIMA', 'UCM', 'ML']].to_csv(path+'830647_20220109.csv', index=False, float_format='%.4f')
